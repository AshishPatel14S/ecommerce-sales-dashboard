# %% [markdown]
# # E-commerce Sales - Data Exploration
#
# **Objective:** Explore and understand the raw dataset before cleaning and analysis.
#
# **Dataset:** UCI Online Retail II
# **Author:** Ashish Patel
# **Date:** 2026-05-26

# %% [markdown]
# ## 1. Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

plt.style.use('seaborn-v0_8-whitegrid')
pd.set_option('display.max_columns', 50)

print('✅ Libraries loaded')
# Out:
# ✅ Libraries loaded

# %%
# Load data
# Option 1: Full dataset (download from UCI)
try:
    df1 = pd.read_excel('../data/raw/online_retail_II.xlsx', sheet_name='Year 2009-2010')
    df2 = pd.read_excel('../data/raw/online_retail_II.xlsx', sheet_name='Year 2010-2011')
    df = pd.concat([df1, df2], ignore_index=True)
    print(f'✅ Loaded full dataset: {len(df):,} rows')
except FileNotFoundError:
    # Option 2: Sample data
    df = pd.read_csv('../data/sample/sample_data.csv')
    print(f'⚠️ Using sample data: {len(df):,} rows')

df.head()
# Out:
# ⚠️ Using sample data: 7,143 rows
#    Invoice StockCode                    Description  Quantity  \
# 0   537618     22423       REGENCY CAKESTAND 3 TIER         1
# 1   537618    84029E  RED WOOLLY HOTTIE WHITE HEART         1
# 2   537618     22727       ALARM CLOCK BAKELIKE RED         9
# 3   537618     22198       SMALL HEART FLOWERS HOOK         3
# 4   536478     71053            WHITE METAL LANTERN        21
#
#            InvoiceDate  Price  Customer ID         Country  Revenue  Year  \
# 0  2010-01-01 12:31:00  12.22        12670  United Kingdom    12.22  2010
# 1  2010-01-01 12:31:00   3.62        12670  United Kingdom     3.62  2010
# 2  2010-01-01 12:31:00   3.53        12670  United Kingdom    31.77  2010
# 3  2010-01-01 12:31:00   0.93        12670  United Kingdom     2.79  2010
# 4  2010-01-01 14:12:00   3.30        12364  United Kingdom    69.30  2010
#
#    Month YearMonth  DayOfWeek  Hour
# 0      1   2010-01          4    12
# 1      1   2010-01          4    12
# 2      1   2010-01          4    12
# 3      1   2010-01          4    12
# 4      1   2010-01          4    14

# %% [markdown]
# ## 2. Basic Structure

# %%
print('📊 Dataset Structure')
print('=' * 50)
print(f'Rows: {len(df):,}')
print(f'Columns: {len(df.columns)}')
print(f'\nColumn Names:')
for col in df.columns:
    print(f'  - {col}')
# Out:
# 📊 Dataset Structure
# ==================================================
# Rows: 7,143
# Columns: 14
#
# Column Names:
#   - Invoice
#   - StockCode
#   - Description
#   - Quantity
#   - InvoiceDate
#   - Price
#   - Customer ID
#   - Country
#   - Revenue
#   - Year
#   - Month
#   - YearMonth
#   - DayOfWeek
#   - Hour

# %%
# Data types
print('\n📋 Data Types')
print('=' * 50)
print(df.dtypes)
# Out:
# 📋 Data Types
# ==================================================
# Invoice          int64
# StockCode       object
# Description     object
# Quantity         int64
# InvoiceDate     object
# Price          float64
# Customer ID      int64
# Country         object
# Revenue        float64
# Year             int64
# Month            int64
# YearMonth       object
# DayOfWeek        int64
# Hour             int64
# dtype: object

# %%
# Memory usage
print(f'\n💾 Memory Usage: {df.memory_usage(deep=True).sum() / 1024**2:.2f} MB')
# Out:
# 💾 Memory Usage: 2.90 MB

# %% [markdown]
# ## 3. Missing Values

# %%
# Missing values summary
missing = pd.DataFrame({
    'Missing': df.isnull().sum(),
    'Percent': (df.isnull().sum() / len(df) * 100).round(2)
}).sort_values('Missing', ascending=False)

print('📋 Missing Values')
print('=' * 50)
print(missing[missing['Missing'] > 0])
# Out:
# 📋 Missing Values
# ==================================================
# Empty DataFrame
# Columns: [Missing, Percent]
# Index: []

# %%
# Visualize missing values
if missing['Missing'].sum() > 0:
    fig, ax = plt.subplots(figsize=(10, 4))
    missing_cols = missing[missing['Missing'] > 0]
    ax.barh(missing_cols.index, missing_cols['Percent'])
    ax.set_xlabel('Missing %')
    ax.set_title('Missing Values by Column', fontweight='bold')
    plt.tight_layout()
    plt.show()

print('\n💡 INSIGHT: Customer ID has missing values — these are likely guest checkouts')
# Out:
# 💡 INSIGHT: Customer ID has missing values — these are likely guest checkouts

# %% [markdown]
# ## 4. Numeric Columns

# %%
# Numeric summary
print('📊 Numeric Summary')
print('=' * 50)
df.describe()
# Out:
# 📊 Numeric Summary
# ==================================================
#              Invoice     Quantity        Price   Customer ID      Revenue  \
# count    7143.000000  7143.000000  7143.000000   7143.000000  7143.000000
# mean   537369.647207     7.336273     3.922449  12615.224696    25.843234
# std       579.942170     8.793727     3.583505    151.125934    40.481418
# min    536365.000000     1.000000     0.000000  12346.000000     0.000000
# 25%    536868.000000     1.500000     1.750000  12486.000000     4.120000
# 50%    537363.000000     4.000000     2.940000  12607.000000    11.730000
# 75%    537883.000000    10.000000     4.750000  12757.000000    30.515000
# max    538364.000000    72.000000    19.760000  12845.000000   405.720000
#
#              Year        Month    DayOfWeek         Hour
# count  7143.00000  7143.000000  7143.000000  7143.000000
# mean   2010.51687     7.261515     3.068599    10.873863
# std       0.49975     3.481951     2.011532     3.957336
# min    2010.00000     1.000000     0.000000     0.000000
# 25%    2010.00000     4.000000     1.000000     9.000000
# 50%    2011.00000     8.000000     3.000000    11.000000
# 75%    2011.00000    10.000000     5.000000    13.000000
# max    2011.00000    12.000000     6.000000    23.000000

# %%
# Check for anomalies
print('\n⚠️ Potential Issues')
print('=' * 50)

# Negative quantities
neg_qty = (df['Quantity'] < 0).sum()
print(f'Negative Quantity: {neg_qty:,} rows ({neg_qty/len(df)*100:.1f}%)')

# Zero or negative prices
zero_price = (df['Price'] <= 0).sum()
print(f'Zero/Negative Price: {zero_price:,} rows ({zero_price/len(df)*100:.1f}%)')

print('\n💡 INSIGHT: Negative quantities are likely returns/cancellations')
# Out:
# ⚠️ Potential Issues
# ==================================================
# Negative Quantity: 0 rows (0.0%)
# Zero/Negative Price: 154 rows (2.2%)
#
# 💡 INSIGHT: Negative quantities are likely returns/cancellations

# %%
# Distribution plots
fig, axes = plt.subplots(1, 2, figsize=(14, 4))

# Quantity distribution (clip for visibility)
qty_clipped = df['Quantity'].clip(-100, 500)
axes[0].hist(qty_clipped, bins=50, edgecolor='black', alpha=0.7)
axes[0].set_xlabel('Quantity')
axes[0].set_ylabel('Frequency')
axes[0].set_title('Quantity Distribution (clipped)', fontweight='bold')

# Price distribution (clip for visibility)
price_clipped = df['Price'].clip(0, 50)
axes[1].hist(price_clipped, bins=50, edgecolor='black', alpha=0.7)
axes[1].set_xlabel('Price (£)')
axes[1].set_ylabel('Frequency')
axes[1].set_title('Price Distribution (clipped at £50)', fontweight='bold')

plt.tight_layout()
plt.savefig('../docs/img/distributions.png', dpi=150)
plt.show()

# %% [markdown]
# ## 5. Categorical Columns

# %%
# Unique values
print('📊 Categorical Columns')
print('=' * 50)
print(f"Unique Invoices: {df['Invoice'].nunique():,}")
print(f"Unique Stock Codes: {df['StockCode'].nunique():,}")
print(f"Unique Customers: {df['Customer ID'].nunique():,}")
print(f"Unique Countries: {df['Country'].nunique()}")
# Out:
# 📊 Categorical Columns
# ==================================================
# Unique Invoices: 2,000
# Unique Stock Codes: 50
# Unique Customers: 452
# Unique Countries: 19

# %%
# Country distribution
print('\n🌍 Top 10 Countries')
print('=' * 50)
country_counts = df['Country'].value_counts().head(10)
print(country_counts)
# Out:
# 🌍 Top 10 Countries
# ==================================================
# Country
# United Kingdom    5908
# Germany            265
# France             247
# Belgium            120
# EIRE               103
# Spain               90
# Switzerland         47
# Italy               47
# Netherlands         44
# Sweden              40
# Name: count, dtype: int64

# %%
# Invoice patterns
print('\n📋 Invoice Patterns')
print('=' * 50)

# Cancellations (start with 'C')
df['IsCancellation'] = df['Invoice'].astype(str).str.startswith('C')
cancellations = df['IsCancellation'].sum()
print(f"Cancellations: {cancellations:,} rows ({cancellations/len(df)*100:.1f}%)")

print('\n💡 INSIGHT: Cancellations need to be handled separately in analysis')
# Out:
# 📋 Invoice Patterns
# ==================================================
# Cancellations: 0 rows (0.0%)
#
# 💡 INSIGHT: Cancellations need to be handled separately in analysis

# %% [markdown]
# ## 6. Date/Time Analysis

# %%
# Convert to datetime if needed
if df['InvoiceDate'].dtype == 'object':
    df['InvoiceDate'] = pd.to_datetime(df['InvoiceDate'])

print('📅 Date Range')
print('=' * 50)
print(f"Start: {df['InvoiceDate'].min()}")
print(f"End: {df['InvoiceDate'].max()}")
print(f"Span: {(df['InvoiceDate'].max() - df['InvoiceDate'].min()).days} days")
# Out:
# 📅 Date Range
# ==================================================
# Start: 2010-01-01 12:31:00
# End: 2011-12-31 17:22:00
# Span: 729 days

# %%
# Transactions over time
daily_orders = df.groupby(df['InvoiceDate'].dt.date).size()

fig, ax = plt.subplots(figsize=(14, 4))
ax.plot(daily_orders.index, daily_orders.values, linewidth=0.8)
ax.set_xlabel('Date')
ax.set_ylabel('Transactions')
ax.set_title('Daily Transaction Volume', fontweight='bold')
plt.tight_layout()
plt.savefig('../docs/img/daily_transactions.png', dpi=150)
plt.show()

# %% [markdown]
# ## 7. Data Quality Summary

# %%
print('=' * 60)
print('📊 DATA QUALITY SUMMARY')
print('=' * 60)

print(f"""
DATASET OVERVIEW:
• Total rows: {len(df):,}
• Date range: {df['InvoiceDate'].min().date()} to {df['InvoiceDate'].max().date()}
• Countries: {df['Country'].nunique()}
• Customers: {df['Customer ID'].nunique():,}

DATA QUALITY ISSUES:
1. Missing Customer IDs: {df['Customer ID'].isnull().sum():,} rows ({df['Customer ID'].isnull().mean()*100:.1f}%)
   → Likely guest checkouts, exclude from customer analysis

2. Negative Quantities: {neg_qty:,} rows ({neg_qty/len(df)*100:.1f}%)
   → Returns/cancellations, handle separately

3. Zero/Negative Prices: {zero_price:,} rows ({zero_price/len(df)*100:.1f}%)
   → Free items or data entry errors, review before excluding

4. Cancellations: {cancellations:,} rows ({cancellations/len(df)*100:.1f}%)
   → Invoices starting with 'C', exclude from revenue calculations

NEXT STEPS:
→ Proceed to 02_data_cleaning.ipynb to address these issues
""")
# Out:
# ============================================================
# 📊 DATA QUALITY SUMMARY
# ============================================================
#
# DATASET OVERVIEW:
# • Total rows: 7,143
# • Date range: 2010-01-01 to 2011-12-31
# • Countries: 19
# • Customers: 452
#
# DATA QUALITY ISSUES:
# 1. Missing Customer IDs: 0 rows (0.0%)
#    → Likely guest checkouts, exclude from customer analysis
#
# 2. Negative Quantities: 0 rows (0.0%)
#    → Returns/cancellations, handle separately
#
# 3. Zero/Negative Prices: 154 rows (2.2%)
#    → Free items or data entry errors, review before excluding
#
# 4. Cancellations: 0 rows (0.0%)
#    → Invoices starting with 'C', exclude from revenue calculations
#
# NEXT STEPS:
# → Proceed to 02_data_cleaning.ipynb to address these issues
